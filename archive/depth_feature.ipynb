# %%
import os
import numpy as np
def get_filelist(home_dir):
    filelist = []
    for dirpath, dirnames, filenames in os.walk(home_dir):
        for filename in filenames:
            fn = os.path.join(dirpath,filename)
            filelist.append(fn)
    filelist = sorted(filelist)
    return filelist



depthlist = get_filelist('~/work/data/cloth2/right/depth')
rgblist = get_filelist('~/work/data/cloth2/right/rgb')

# %%
import cv2
import matplotlib.pyplot as plt

i = 1
depth = cv2.imread(depthlist[i], cv2.IMREAD_UNCHANGED)
plt.imshow(depth), plt.show()
print np.min(depth)
# histr = cv2.calcHist([depth],[0],None,[80000],[0,2000])
# plt.plot(histr,color = col), plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-a0dc81bd1e97> in <module>()
#       3
#       4 i = 1
# ----> 5 depth = cv2.imread(depthlist[i], cv2.IMREAD_UNCHANGED)
#       6 plt.imshow(depth), plt.show()
#       7 print np.min(depth)
#
# IndexError: list index out of range

# %%
i = 1
def get_fg(img):
    markers = np.uint8(np.zeros((480,640)))
    markers[420:, 300:360] =1
    # set background as 2
    markers[:,0:20] = 2
    markers[:,-20:] = 2
    #markers[0:20,:] = 2
    markers_rgb = markers.astype(np.int32)
    markers_rgb = cv2.watershed(img,markers_rgb)
    fg = np.uint8(markers_rgb == 1)
    return fg

def mk(s):#morph kernel
    return np.ones((s,s),np.uint8)

def shrink(fg):
    shrink_fg = cv2.erode(fg, mk(15), iterations = 2)
    return shrink_fg

for i in range(0,len(depthlist),90):
    depth = cv2.imread(depthlist[i],cv2.IMREAD_UNCHANGED)
    plt.imshow(depth), plt.show()
    rgb = cv2.imread(rgblist[i])
    fg = get_fg(rgb)
    #fg = shrink(fg)
    depth = cv2.bitwise_and(depth,depth,mask = fg)
    plt.imshow(depth)
    plt.show()

# %%
def gabor_feat_depth(img, num_theta = 4,show_step=False):    
    ks = 101 # kernel size
    rows, cols = img.shape[:2]
    avg = np.zeros(img.shape[:2])
    count = 0
    grid = 80
    
    hist = []
    for i in range(num_theta):
        g_kernel1 = cv2.getGaborKernel((ks, ks), sigma = 6.0, theta = i*np.pi/num_theta, lambd = 8.0, gamma=0.5, psi=0, ktype=cv2.CV_32F)
        filtered = cv2.filter2D(img, cv2.CV_8UC3, g_kernel1)
        
        for col in np.arange(0, cols, grid):
            for row in np.arange(0, rows, grid):
                block = filtered[row:row+grid,col:col+grid]
                val =  np.sum(block)
                hist.append(val)
        
        
        avg = avg + filtered
        if show_step:
            plt.imshow(filtered)
            plt.show()
    
    avg = avg/num_theta
    return avg, hist

def grid_feat(img):
    hist = []
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    rows, cols = gray.shape
    grid = 20
    for col in np.arange(0, cols, grid):
        for row in np.arange(0, rows, grid):
            block = gray[row:row+grid,col:col+grid]
            val =  np.sum(block)
            hist.append(val)
    return hist


i = 900
depth = cv2.imread(depthlist[i],cv2.IMREAD_UNCHANGED)
plt.imshow(depth),plt.show()
avg,hist = gabor_feat_depth(depth, show_step=False)
plt.imshow(avg),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f61c4494650>, None)

# %%
for i in range(0,len(depthlist),90):
    depth = cv2.imread(depthlist[i],cv2.IMREAD_UNCHANGED)
    plt.imshow(depth), plt.show()
    rgb = cv2.imread(rgblist[i])
    fg = get_fg(rgb)
    depth = cv2.bitwise_and(depth,depth,mask = fg)
    avg,hist = gabor_feat(depth, show_step=False)
    plt.imshow(avg),plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-22-5d783cb9d74f> in <module>()
#       5     fg = get_fg(rgb)
#       6     depth = cv2.bitwise_and(depth,depth,mask = fg)
# ----> 7     avg,hist = gabor_feat(depth, show_step=False)
#       8     plt.imshow(avg),plt.show()
#
# <ipython-input-19-971f4239517b> in gabor_feat(img, num_theta, show_fg, show_step)
#       1 def gabor_feat(img, num_theta = 4, show_fg=False,show_step=False):
# ----> 2     img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       3     fg = get_fg(img)
#       4     shrink_fg = cv2.erode(fg, mk(15), iterations = 2)
#       5
#
# error: /tmp/binarydeb/ros-kinetic-opencv3-3.2.0/modules/imgproc/src/color.cpp:9716: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
# build up the dataset
feat = np.array([])
for i in range(len(rgblist)):
    depth = cv2.imread(depthlist[i])
    hist = grid_feat(depth)
    hist = np.array(hist)
    feat = np.vstack((feat,hist)) if feat.size else hist
    print feat.shape

# find the edges
data = np.load('data.npz')
vel = data['vel']
pos = data['pos']
print feat.shape
print pos.shape
print vel.shape
np.savez('data2_depth_grid',pos=pos,vel=vel,feat=feat)
# Out:
# (768,)
# (2, 768)
# (3, 768)
# (4, 768)
# (5, 768)
# (6, 768)
# (7, 768)
# (8, 768)
# (9, 768)
# (10, 768)
# (11, 768)
# (12, 768)
# (13, 768)
# (14, 768)
# (15, 768)
# (16, 768)
# (17, 768)
# (18, 768)
# (19, 768)
# (20, 768)
# (21, 768)
# (22, 768)
# (23, 768)
# (24, 768)
# (25, 768)
# (26, 768)
# (27, 768)
# (28, 768)
# (29, 768)
# (30, 768)
# (31, 768)
# (32, 768)
# (33, 768)
# (34, 768)
# (35, 768)
# (36, 768)
# (37, 768)
# (38, 768)
# (39, 768)
# (40, 768)
# (41, 768)
# (42, 768)
# (43, 768)
# (44, 768)
# (45, 768)
# (46, 768)
# (47, 768)
# (48, 768)
# (49, 768)
# (50, 768)
# (51, 768)
# (52, 768)
# (53, 768)
# (54, 768)
# (55, 768)
# (56, 768)
# (57, 768)
# (58, 768)
# (59, 768)
# (60, 768)
# (61, 768)
# (62, 768)
# (63, 768)
# (64, 768)
# (65, 768)
# (66, 768)
# (67, 768)
# (68, 768)
# (69, 768)
# (70, 768)
# (71, 768)
# (72, 768)
# (73, 768)
# (74, 768)
# (75, 768)
# (76, 768)
# (77, 768)
# (78, 768)
# (79, 768)
# (80, 768)
# (81, 768)
# (82, 768)
# (83, 768)
# (84, 768)
# (85, 768)
# (86, 768)
# (87, 768)
# (88, 768)
# (89, 768)
# (90, 768)
# (91, 768)
# (92, 768)
# (93, 768)
# (94, 768)
# (95, 768)
# (96, 768)
# (97, 768)
# (98, 768)
# (99, 768)
# (100, 768)
# (101, 768)
# (102, 768)
# (103, 768)
# (104, 768)
# (105, 768)
# (106, 768)
# (107, 768)
# (108, 768)
# (109, 768)
# (110, 768)
# (111, 768)
# (112, 768)
# (113, 768)
# (114, 768)
# (115, 768)
# (116, 768)
# (117, 768)
# (118, 768)
# (119, 768)
# (120, 768)
# (121, 768)
# (122, 768)
# (123, 768)
# (124, 768)
# (125, 768)
# (126, 768)
# (127, 768)
# (128, 768)
# (129, 768)
# (130, 768)
# (131, 768)
# (132, 768)
# (133, 768)
# (134, 768)
# (135, 768)
# (136, 768)
# (137, 768)
# (138, 768)
# (139, 768)
# (140, 768)
# (141, 768)
# (142, 768)
# (143, 768)
# (144, 768)
# (145, 768)
# (146, 768)
# (147, 768)
# (148, 768)
# (149, 768)
# (150, 768)
# (151, 768)
# (152, 768)
# (153, 768)
# (154, 768)
# (155, 768)
# (156, 768)
# (157, 768)
# (158, 768)
# (159, 768)
# (160, 768)
# (161, 768)
# (162, 768)
# (163, 768)
# (164, 768)
# (165, 768)
# (166, 768)
# (167, 768)
# (168, 768)
# (169, 768)
# (170, 768)
# (171, 768)
# (172, 768)
# (173, 768)
# (174, 768)
# (175, 768)
# (176, 768)
# (177, 768)
# (178, 768)
# (179, 768)
# (180, 768)
# (181, 768)
# (182, 768)
# (183, 768)
# (184, 768)
# (185, 768)
# (186, 768)
# (187, 768)
# (188, 768)
# (189, 768)
# (190, 768)
# (191, 768)
# (192, 768)
# (193, 768)
# (194, 768)
# (195, 768)
# (196, 768)
# (197, 768)
# (198, 768)
# (199, 768)
# (200, 768)
# (201, 768)
# (202, 768)
# (203, 768)
# (204, 768)
# (205, 768)
# (206, 768)
# (207, 768)
# (208, 768)
# (209, 768)
# (210, 768)
# (211, 768)
# (212, 768)
# (213, 768)
# (214, 768)
# (215, 768)
# (216, 768)
# (217, 768)
# (218, 768)
# (219, 768)
# (220, 768)
# (221, 768)
# (222, 768)
# (223, 768)
# (224, 768)
# (225, 768)
# (226, 768)
# (227, 768)
# (228, 768)
# (229, 768)
# (230, 768)
# (231, 768)
# (232, 768)
# (233, 768)
# (234, 768)
# (235, 768)
# (236, 768)
# (237, 768)
# (238, 768)
# (239, 768)
# (240, 768)
# (241, 768)
# (242, 768)
# (243, 768)
# (244, 768)
# (245, 768)
# (246, 768)
# (247, 768)
# (248, 768)
# (249, 768)
# (250, 768)
# (251, 768)
# (252, 768)
# (253, 768)
# (254, 768)
# (255, 768)
# (256, 768)
# (257, 768)
# (258, 768)
# (259, 768)
# (260, 768)
# (261, 768)
# (262, 768)
# (263, 768)
# (264, 768)
# (265, 768)
# (266, 768)
# (267, 768)
# (268, 768)
# (269, 768)
# (270, 768)
# (271, 768)
# (272, 768)
# (273, 768)
# (274, 768)
# (275, 768)
# (276, 768)
# (277, 768)
# (278, 768)
# (279, 768)
# (280, 768)
# (281, 768)
# (282, 768)
# (283, 768)
# (284, 768)
# (285, 768)
# (286, 768)
# (287, 768)
# (288, 768)
# (289, 768)
# (290, 768)
# (291, 768)
# (292, 768)
# (293, 768)
# (294, 768)
# (295, 768)
# (296, 768)
# (297, 768)
# (298, 768)
# (299, 768)
# (300, 768)
# (301, 768)
# (302, 768)
# (303, 768)
# (304, 768)
# (305, 768)
# (306, 768)
# (307, 768)
# (308, 768)
# (309, 768)
# (310, 768)
# (311, 768)
# (312, 768)
# (313, 768)
# (314, 768)
# (315, 768)
# (316, 768)
# (317, 768)
# (318, 768)
# (319, 768)
# (320, 768)
# (321, 768)
# (322, 768)
# (323, 768)
# (324, 768)
# (325, 768)
# (326, 768)
# (327, 768)
# (328, 768)
# (329, 768)
# (330, 768)
# (331, 768)
# (332, 768)
# (333, 768)
# (334, 768)
# (335, 768)
# (336, 768)
# (337, 768)
# (338, 768)
# (339, 768)
# (340, 768)
# (341, 768)
# (342, 768)
# (343, 768)
# (344, 768)
# (345, 768)
# (346, 768)
# (347, 768)
# (348, 768)
# (349, 768)
# (350, 768)
# (351, 768)
# (352, 768)
# (353, 768)
# (354, 768)
# (355, 768)
# (356, 768)
# (357, 768)
# (358, 768)
# (359, 768)
# (360, 768)
# (361, 768)
# (362, 768)
# (363, 768)
# (364, 768)
# (365, 768)
# (366, 768)
# (367, 768)
# (368, 768)
# (369, 768)
# (370, 768)
# (371, 768)
# (372, 768)
# (373, 768)
# (374, 768)
# (375, 768)
# (376, 768)
# (377, 768)
# (378, 768)
# (379, 768)
# (380, 768)
# (381, 768)
# (382, 768)
# (383, 768)
# (384, 768)
# (385, 768)
# (386, 768)
# (387, 768)
# (388, 768)
# (389, 768)
# (390, 768)
# (391, 768)
# (392, 768)
# (393, 768)
# (394, 768)
# (395, 768)
# (396, 768)
# (397, 768)
# (398, 768)
# (399, 768)
# (400, 768)
# (401, 768)
# (402, 768)
# (403, 768)
# (404, 768)
# (405, 768)
# (406, 768)
# (407, 768)
# (408, 768)
# (409, 768)
# (410, 768)
# (411, 768)
# (412, 768)
# (413, 768)
# (414, 768)
# (415, 768)
# (416, 768)
# (417, 768)
# (418, 768)
# (419, 768)
# (420, 768)
# (421, 768)
# (422, 768)
# (423, 768)
# (424, 768)
# (425, 768)
# (426, 768)
# (427, 768)
# (428, 768)
# (429, 768)
# (430, 768)
# (431, 768)
# (432, 768)
# (433, 768)
# (434, 768)
# (435, 768)
# (436, 768)
# (437, 768)
# (438, 768)
# (439, 768)
# (440, 768)
# (441, 768)
# (442, 768)
# (443, 768)
# (444, 768)
# (445, 768)
# (446, 768)
# (447, 768)
# (448, 768)
# (449, 768)
# (450, 768)
# (451, 768)
# (452, 768)
# (453, 768)
# (454, 768)
# (455, 768)
# (456, 768)
# (457, 768)
# (458, 768)
# (459, 768)
# (460, 768)
# (461, 768)
# (462, 768)
# (463, 768)
# (464, 768)
# (465, 768)
# (466, 768)
# (467, 768)
# (468, 768)
# (469, 768)
# (470, 768)
# (471, 768)
# (472, 768)
# (473, 768)
# (474, 768)
# (475, 768)
# (476, 768)
# (477, 768)
# (478, 768)
# (479, 768)
# (480, 768)
# (481, 768)
# (482, 768)
# (483, 768)
# (484, 768)
# (485, 768)
# (486, 768)
# (487, 768)
# (488, 768)
# (489, 768)
# (490, 768)
# (491, 768)
# (492, 768)
# (493, 768)
# (494, 768)
# (495, 768)
# (496, 768)
# (497, 768)
# (498, 768)
# (499, 768)
# (500, 768)
# (501, 768)
# (502, 768)
# (503, 768)
# (504, 768)
# (505, 768)
# (506, 768)
# (507, 768)
# (508, 768)
# (509, 768)
# (510, 768)
# (511, 768)
# (512, 768)
# (513, 768)
# (514, 768)
# (515, 768)
# (516, 768)
# (517, 768)
# (518, 768)
# (519, 768)
# (520, 768)
# (521, 768)
# (522, 768)
# (523, 768)
# (524, 768)
# (525, 768)
# (526, 768)
# (527, 768)
# (528, 768)
# (529, 768)
# (530, 768)
# (531, 768)
# (532, 768)
# (533, 768)
# (534, 768)
# (535, 768)
# (536, 768)
# (537, 768)
# (538, 768)
# (539, 768)
# (540, 768)
# (541, 768)
# (542, 768)
# (543, 768)
# (544, 768)
# (545, 768)
# (546, 768)
# (547, 768)
# (548, 768)
# (549, 768)
# (550, 768)
# (551, 768)
# (552, 768)
# (553, 768)
# (554, 768)
# (555, 768)
# (556, 768)
# (557, 768)
# (558, 768)
# (559, 768)
# (560, 768)
# (561, 768)
# (562, 768)
# (563, 768)
# (564, 768)
# (565, 768)
# (566, 768)
# (567, 768)
# (568, 768)
# (569, 768)
# (570, 768)
# (571, 768)
# (572, 768)
# (573, 768)
# (574, 768)
# (575, 768)
# (576, 768)
# (577, 768)
# (578, 768)
# (579, 768)
# (580, 768)
# (581, 768)
# (582, 768)
# (583, 768)
# (584, 768)
# (585, 768)
# (586, 768)
# (587, 768)
# (588, 768)
# (589, 768)
# (590, 768)
# (591, 768)
# (592, 768)
# (593, 768)
# (594, 768)
# (595, 768)
# (596, 768)
# (597, 768)
# (598, 768)
# (599, 768)
# (600, 768)
# (601, 768)
# (602, 768)
# (603, 768)
# (604, 768)
# (605, 768)
# (606, 768)
# (607, 768)
# (608, 768)
# (609, 768)
# (610, 768)
# (611, 768)
# (612, 768)
# (613, 768)
# (614, 768)
# (615, 768)
# (616, 768)
# (617, 768)
# (618, 768)
# (619, 768)
# (620, 768)
# (621, 768)
# (622, 768)
# (623, 768)
# (624, 768)
# (625, 768)
# (626, 768)
# (627, 768)
# (628, 768)
# (629, 768)
# (630, 768)
# (631, 768)
# (632, 768)
# (633, 768)
# (634, 768)
# (635, 768)
# (636, 768)
# (637, 768)
# (638, 768)
# (639, 768)
# (640, 768)
# (641, 768)
# (642, 768)
# (643, 768)
# (644, 768)
# (645, 768)
# (646, 768)
# (647, 768)
# (648, 768)
# (649, 768)
# (650, 768)
# (651, 768)
# (652, 768)
# (653, 768)
# (654, 768)
# (655, 768)
# (656, 768)
# (657, 768)
# (658, 768)
# (659, 768)
# (660, 768)
# (661, 768)
# (662, 768)
# (663, 768)
# (664, 768)
# (665, 768)
# (666, 768)
# (667, 768)
# (668, 768)
# (669, 768)
# (670, 768)
# (671, 768)
# (672, 768)
# (673, 768)
# (674, 768)
# (675, 768)
# (676, 768)
# (677, 768)
# (678, 768)
# (679, 768)
# (680, 768)
# (681, 768)
# (682, 768)
# (683, 768)
# (684, 768)
# (685, 768)
# (686, 768)
# (687, 768)
# (688, 768)
# (689, 768)
# (690, 768)
# (691, 768)
# (692, 768)
# (693, 768)
# (694, 768)
# (695, 768)
# (696, 768)
# (697, 768)
# (698, 768)
# (699, 768)
# (700, 768)
# (701, 768)
# (702, 768)
# (703, 768)
# (704, 768)
# (705, 768)
# (706, 768)
# (707, 768)
# (708, 768)
# (709, 768)
# (710, 768)
# (711, 768)
# (712, 768)
# (713, 768)
# (714, 768)
# (715, 768)
# (716, 768)
# (717, 768)
# (718, 768)
# (719, 768)
# (720, 768)
# (721, 768)
# (722, 768)
# (723, 768)
# (724, 768)
# (725, 768)
# (726, 768)
# (727, 768)
# (728, 768)
# (729, 768)
# (730, 768)
# (731, 768)
# (732, 768)
# (733, 768)
# (734, 768)
# (735, 768)
# (736, 768)
# (737, 768)
# (738, 768)
# (739, 768)
# (740, 768)
# (741, 768)
# (742, 768)
# (743, 768)
# (744, 768)
# (745, 768)
# (746, 768)
# (747, 768)
# (748, 768)
# (749, 768)
# (750, 768)
# (751, 768)
# (752, 768)
# (753, 768)
# (754, 768)
# (755, 768)
# (756, 768)
# (757, 768)
# (758, 768)
# (759, 768)
# (760, 768)
# (761, 768)
# (762, 768)
# (763, 768)
# (764, 768)
# (765, 768)
# (766, 768)
# (767, 768)
# (768, 768)
# (769, 768)
# (770, 768)
# (771, 768)
# (772, 768)
# (773, 768)
# (774, 768)
# (775, 768)
# (776, 768)
# (777, 768)
# (778, 768)
# (779, 768)
# (780, 768)
# (781, 768)
# (782, 768)
# (783, 768)
# (784, 768)
# (785, 768)
# (786, 768)
# (787, 768)
# (788, 768)
# (789, 768)
# (790, 768)
# (791, 768)
# (792, 768)
# (793, 768)
# (794, 768)
# (795, 768)
# (796, 768)
# (797, 768)
# (798, 768)
# (799, 768)
# (800, 768)
# (801, 768)
# (802, 768)
# (803, 768)
# (804, 768)
# (805, 768)
# (806, 768)
# (807, 768)
# (808, 768)
# (809, 768)
# (810, 768)
# (811, 768)
# (812, 768)
# (813, 768)
# (814, 768)
# (815, 768)
# (816, 768)
# (817, 768)
# (818, 768)
# (819, 768)
# (820, 768)
# (821, 768)
# (822, 768)
# (823, 768)
# (824, 768)
# (825, 768)
# (826, 768)
# (827, 768)
# (828, 768)
# (829, 768)
# (830, 768)
# (831, 768)
# (832, 768)
# (833, 768)
# (834, 768)
# (835, 768)
# (836, 768)
# (837, 768)
# (838, 768)
# (839, 768)
# (840, 768)
# (841, 768)
# (842, 768)
# (843, 768)
# (844, 768)
# (845, 768)
# (846, 768)
# (847, 768)
# (848, 768)
# (849, 768)
# (850, 768)
# (851, 768)
# (852, 768)
# (853, 768)
# (854, 768)
# (855, 768)
# (856, 768)
# (857, 768)
# (858, 768)
# (859, 768)
# (860, 768)
# (861, 768)
# (862, 768)
# (863, 768)
# (864, 768)
# (865, 768)
# (866, 768)
# (867, 768)
# (868, 768)
# (869, 768)
# (870, 768)
# (871, 768)
# (872, 768)
# (873, 768)
# (874, 768)
# (875, 768)
# (876, 768)
# (877, 768)
# (878, 768)
# (879, 768)
# (880, 768)
# (881, 768)
# (882, 768)
# (883, 768)
# (884, 768)
# (885, 768)
# (886, 768)
# (887, 768)
# (888, 768)
# (889, 768)
# (890, 768)
# (891, 768)
# (892, 768)
# (893, 768)
# (894, 768)
# (895, 768)
# (896, 768)
# (897, 768)
# (898, 768)
# (899, 768)
# (900, 768)
# (901, 768)
# (902, 768)
# (903, 768)
# (904, 768)
# (905, 768)
# (906, 768)
# (907, 768)
# (908, 768)
# (909, 768)
# (910, 768)
# (911, 768)
# (912, 768)
# (913, 768)
# (914, 768)
# (915, 768)
# (916, 768)
# (917, 768)
# (918, 768)
# (919, 768)
# (920, 768)
# (921, 768)
# (922, 768)
# (923, 768)
# (924, 768)
# (925, 768)
# (926, 768)
# (927, 768)
# (928, 768)
# (929, 768)
# (930, 768)
# (931, 768)
# (932, 768)
# (933, 768)
# (934, 768)
# (935, 768)
# (936, 768)
# (937, 768)
# (938, 768)
# (939, 768)
# (940, 768)
# (941, 768)
# (942, 768)
# (943, 768)
# (944, 768)
# (945, 768)
# (946, 768)
# (947, 768)
# (948, 768)
# (949, 768)
# (950, 768)
# (951, 768)
# (952, 768)
# (953, 768)
# (954, 768)
# (955, 768)
# (956, 768)
# (957, 768)
# (958, 768)
# (959, 768)
# (960, 768)
# (961, 768)
# (962, 768)
# (963, 768)
# (964, 768)
# (965, 768)
# (966, 768)
# (967, 768)
# (968, 768)
# (969, 768)
# (970, 768)
# (971, 768)
# (972, 768)
# (973, 768)
# (974, 768)
# (975, 768)
# (976, 768)
# (977, 768)
# (978, 768)
# (979, 768)
# (980, 768)
# (981, 768)
# (982, 768)
# (983, 768)
# (984, 768)
# (985, 768)
# (986, 768)
# (987, 768)
# (988, 768)
# (989, 768)
# (990, 768)
# (991, 768)
# (992, 768)
# (993, 768)
# (994, 768)
# (995, 768)
# (996, 768)
# (997, 768)
# (998, 768)
# (999, 768)
# (1000, 768)
# (1001, 768)
# (1002, 768)
# (1003, 768)
# (1004, 768)
# (1005, 768)
# (1006, 768)
# (1007, 768)
# (1008, 768)
# (1009, 768)
# (1010, 768)
# (1011, 768)
# (1012, 768)
# (1013, 768)
# (1014, 768)
# (1015, 768)
# (1016, 768)
# (1017, 768)
# (1018, 768)
# (1019, 768)
# (1020, 768)
# (1021, 768)
# (1022, 768)
# (1023, 768)
# (1024, 768)
# (1025, 768)
# (1026, 768)
# (1027, 768)
# (1028, 768)
# (1029, 768)
# (1030, 768)
# (1031, 768)
# (1032, 768)
# (1033, 768)
# (1034, 768)
# (1035, 768)
# (1036, 768)
# (1037, 768)
# (1038, 768)
# (1039, 768)
# (1040, 768)
# (1041, 768)
# (1042, 768)
# (1043, 768)
# (1044, 768)
# (1045, 768)
# (1046, 768)
# (1047, 768)
# (1048, 768)
# (1049, 768)
# (1050, 768)
# (1051, 768)
# (1052, 768)
# (1053, 768)
# (1054, 768)
# (1055, 768)
# (1056, 768)
# (1057, 768)
# (1058, 768)
# (1059, 768)
# (1060, 768)
# (1061, 768)
# (1062, 768)
# (1063, 768)
# (1064, 768)
# (1065, 768)
# (1066, 768)
# (1067, 768)
# (1068, 768)
# (1069, 768)
# (1070, 768)
# (1071, 768)
# (1072, 768)
# (1073, 768)
# (1074, 768)
# (1075, 768)
# (1076, 768)
# (1077, 768)
# (1078, 768)
# (1079, 768)
# (1080, 768)
# (1081, 768)
# (1082, 768)
# (1083, 768)
# (1084, 768)
# (1085, 768)
# (1086, 768)
# (1087, 768)
# (1088, 768)
# (1089, 768)
# (1090, 768)
# (1091, 768)
# (1092, 768)
# (1093, 768)
# (1094, 768)
# (1095, 768)
# (1096, 768)
# (1097, 768)
# (1098, 768)
# (1099, 768)
# (1100, 768)
# (1101, 768)
# (1102, 768)
# (1103, 768)
# (1104, 768)
# (1105, 768)
# (1106, 768)
# (1107, 768)
# (1108, 768)
# (1109, 768)
# (1110, 768)
# (1111, 768)
# (1112, 768)
# (1113, 768)
# (1114, 768)
# (1115, 768)
# (1116, 768)
# (1117, 768)
# (1118, 768)
# (1119, 768)
# (1120, 768)
# (1121, 768)
# (1122, 768)
# (1123, 768)
# (1124, 768)
# (1125, 768)
# (1126, 768)
# (1127, 768)
# (1128, 768)
# (1129, 768)
# (1130, 768)
# (1131, 768)
# (1132, 768)
# (1133, 768)
# (1134, 768)
# (1135, 768)
# (1136, 768)
# (1137, 768)
# (1138, 768)
# (1139, 768)
# (1140, 768)
# (1141, 768)
# (1142, 768)
# (1143, 768)
# (1144, 768)
# (1145, 768)
# (1146, 768)
# (1147, 768)
# (1148, 768)
# (1149, 768)
# (1150, 768)
# (1151, 768)
# (1152, 768)
# (1153, 768)
# (1154, 768)
# (1155, 768)
# (1156, 768)
# (1157, 768)
# (1158, 768)
# (1159, 768)
# (1160, 768)
# (1161, 768)
# (1162, 768)
# (1163, 768)
# (1164, 768)
# (1165, 768)
# (1166, 768)
# (1167, 768)
# (1168, 768)
# (1169, 768)
# (1170, 768)
# (1171, 768)
# (1172, 768)
# (1173, 768)
# (1174, 768)
# (1175, 768)
# (1176, 768)
# (1177, 768)
# (1178, 768)
# (1179, 768)
# (1180, 768)
# (1181, 768)
# (1182, 768)
# (1183, 768)
# (1184, 768)
# (1185, 768)
# (1186, 768)
# (1187, 768)
# (1188, 768)
# (1189, 768)
# (1190, 768)
# (1191, 768)
# (1192, 768)
# (1193, 768)
# (1194, 768)
# (1195, 768)
# (1196, 768)
# (1197, 768)
# (1198, 768)
# (1199, 768)
# (1200, 768)
# (1201, 768)
# (1202, 768)
# (1203, 768)
# (1204, 768)
# (1205, 768)
# (1206, 768)
# (1207, 768)
# (1208, 768)
# (1209, 768)
# (1210, 768)
# (1211, 768)
# (1212, 768)
# (1213, 768)
# (1214, 768)
# (1215, 768)
# (1216, 768)
# (1217, 768)
# (1218, 768)
# (1219, 768)
# (1220, 768)
# (1221, 768)
# (1222, 768)
# (1223, 768)
# (1224, 768)
# (1225, 768)
# (1226, 768)
# (1227, 768)
# (1228, 768)
# (1229, 768)
# (1230, 768)
# (1231, 768)
# (1232, 768)
# (1233, 768)
# (1234, 768)
# (1235, 768)
# (1236, 768)
# (1237, 768)
# (1238, 768)
# (1239, 768)
# (1240, 768)
# (1241, 768)
# (1242, 768)
# (1243, 768)
# (1244, 768)
# (1245, 768)
# (1246, 768)
# (1247, 768)
# (1248, 768)
# (1249, 768)
# (1250, 768)
# (1251, 768)
# (1252, 768)
# (1253, 768)
# (1254, 768)
# (1255, 768)
# (1256, 768)
# (1257, 768)
# (1258, 768)
# (1259, 768)
# (1260, 768)
# (1261, 768)
# (1262, 768)
# (1263, 768)
# (1264, 768)
# (1265, 768)
# (1266, 768)
# (1267, 768)
# (1268, 768)
# (1269, 768)
# (1270, 768)
# (1271, 768)
# (1272, 768)
# (1273, 768)
# (1274, 768)
# (1275, 768)
# (1276, 768)
# (1277, 768)
# (1278, 768)
# (1279, 768)
# (1280, 768)
# (1281, 768)
# (1282, 768)
# (1283, 768)
# (1284, 768)
# (1285, 768)
# (1286, 768)
# (1287, 768)
# (1288, 768)
# (1289, 768)
# (1290, 768)
# (1291, 768)
# (1292, 768)
# (1293, 768)
# (1294, 768)
# (1295, 768)
# (1296, 768)
# (1297, 768)
# (1298, 768)
# (1299, 768)
# (1300, 768)
# (1301, 768)
# (1302, 768)
# (1303, 768)
# (1304, 768)
# (1305, 768)
# (1306, 768)
# (1307, 768)
# (1308, 768)
# (1309, 768)
# (1310, 768)
# (1311, 768)
# (1312, 768)
# (1313, 768)
# (1314, 768)
# (1315, 768)
# (1316, 768)
# (1317, 768)
# (1318, 768)
# (1319, 768)
# (1320, 768)
# (1321, 768)
# (1322, 768)
# (1323, 768)
# (1324, 768)
# (1325, 768)
# (1326, 768)
# (1327, 768)
# (1328, 768)
# (1329, 768)
# (1330, 768)
# (1331, 768)
# (1332, 768)
# (1333, 768)
# (1334, 768)
# (1335, 768)
# (1336, 768)
# (1337, 768)
# (1338, 768)
# (1339, 768)
# (1340, 768)
# (1341, 768)
# (1342, 768)
# (1343, 768)
# (1344, 768)
# (1345, 768)
# (1346, 768)
# (1347, 768)
# (1348, 768)
# (1349, 768)
# (1350, 768)
# (1351, 768)
# (1352, 768)
# (1353, 768)
# (1354, 768)
# (1355, 768)
# (1356, 768)
# (1357, 768)
# (1358, 768)
# (1359, 768)
# (1360, 768)
# (1361, 768)
# (1362, 768)
# (1363, 768)
# (1364, 768)
# (1365, 768)
# (1366, 768)
# (1367, 768)
# (1368, 768)
# (1369, 768)
# (1370, 768)
# (1371, 768)
# (1372, 768)
# (1373, 768)
# (1374, 768)
# (1375, 768)
# (1376, 768)
# (1377, 768)
# (1378, 768)
# (1379, 768)
# (1380, 768)
# (1381, 768)
# (1382, 768)
# (1383, 768)
# (1384, 768)
# (1385, 768)
# (1386, 768)
# (1387, 768)
# (1388, 768)
# (1389, 768)
# (1390, 768)
# (1391, 768)
# (1392, 768)
# (1393, 768)
# (1394, 768)
# (1395, 768)
# (1396, 768)
# (1397, 768)
# (1398, 768)
# (1399, 768)
# (1400, 768)
# (1401, 768)
# (1402, 768)
# (1403, 768)
# (1404, 768)
# (1405, 768)
# (1406, 768)
# (1407, 768)
# (1408, 768)
# (1409, 768)
# (1410, 768)
# (1411, 768)
# (1412, 768)
# (1413, 768)
# (1414, 768)
# (1415, 768)
# (1416, 768)
# (1417, 768)
# (1418, 768)
# (1419, 768)
# (1420, 768)
# (1421, 768)
# (1422, 768)
# (1423, 768)
# (1424, 768)
# (1425, 768)
# (1426, 768)
# (1427, 768)
# (1428, 768)
# (1429, 768)
# (1430, 768)
# (1431, 768)
# (1432, 768)
# (1433, 768)
# (1434, 768)
# (1435, 768)
# (1436, 768)
# (1437, 768)
# (1438, 768)
# (1439, 768)
# (1440, 768)
# (1441, 768)
# (1442, 768)
# (1443, 768)
# (1444, 768)
# (1445, 768)
# (1446, 768)
# (1447, 768)
# (1448, 768)
# (1449, 768)
# (1450, 768)
# (1451, 768)
# (1452, 768)
# (1453, 768)
# (1454, 768)
# (1455, 768)
# (1456, 768)
# (1457, 768)
# (1458, 768)
# (1459, 768)
# (1460, 768)
# (1461, 768)
# (1462, 768)
# (1463, 768)
# (1464, 768)
# (1465, 768)
# (1466, 768)
# (1467, 768)
# (1468, 768)
# (1469, 768)
# (1470, 768)
# (1471, 768)
# (1472, 768)
# (1473, 768)
# (1474, 768)
# (1475, 768)
# (1476, 768)
# (1477, 768)
# (1478, 768)
# (1479, 768)
# (1480, 768)
# (1481, 768)
# (1482, 768)
# (1483, 768)
# (1484, 768)
# (1485, 768)
# (1486, 768)
# (1487, 768)
# (1488, 768)
# (1489, 768)
# (1490, 768)
# (1491, 768)
# (1492, 768)
# (1493, 768)
# (1494, 768)
# (1495, 768)
# (1496, 768)
# (1497, 768)
# (1498, 768)
# (1499, 768)
# (1500, 768)
# (1501, 768)
# (1502, 768)
# (1503, 768)
# (1504, 768)
# (1505, 768)
# (1506, 768)
# (1507, 768)
# (1508, 768)
# (1509, 768)
# (1510, 768)
# (1511, 768)
# (1512, 768)
# (1513, 768)
# (1514, 768)
# (1515, 768)
# (1516, 768)
# (1517, 768)
# (1518, 768)
# (1519, 768)
# (1520, 768)
# (1521, 768)
# (1522, 768)
# (1523, 768)
# (1524, 768)
# (1525, 768)
# (1526, 768)
# (1527, 768)
# (1528, 768)
# (1529, 768)
# (1530, 768)
# (1531, 768)
# (1532, 768)
# (1533, 768)
# (1534, 768)
# (1535, 768)
# (1536, 768)
# (1537, 768)
# (1538, 768)
# (1539, 768)
# (1540, 768)
# (1541, 768)
# (1542, 768)
# (1543, 768)
# (1544, 768)
# (1545, 768)
# (1546, 768)
# (1547, 768)
# (1548, 768)
# (1549, 768)
# (1550, 768)
# (1551, 768)
# (1552, 768)
# (1553, 768)
# (1554, 768)
# (1555, 768)
# (1556, 768)
# (1557, 768)
# (1558, 768)
# (1559, 768)
# (1560, 768)
# (1561, 768)
# (1562, 768)
# (1563, 768)
# (1564, 768)
# (1565, 768)
# (1566, 768)
# (1567, 768)
# (1568, 768)
# (1569, 768)
# (1570, 768)
# (1571, 768)
# (1572, 768)
# (1573, 768)
# (1574, 768)
# (1575, 768)
# (1576, 768)
# (1577, 768)
# (1578, 768)
# (1579, 768)
# (1580, 768)
# (1581, 768)
# (1582, 768)
# (1583, 768)
# (1584, 768)
# (1585, 768)
# (1586, 768)
# (1587, 768)
# (1588, 768)
# (1589, 768)
# (1590, 768)
# (1591, 768)
# (1592, 768)
# (1593, 768)
# (1594, 768)
# (1595, 768)
# (1596, 768)
# (1597, 768)
# (1598, 768)
# (1599, 768)
# (1600, 768)
# (1601, 768)
# (1602, 768)
# (1603, 768)
# (1604, 768)
# (1605, 768)
# (1606, 768)
# (1607, 768)
# (1608, 768)
# (1609, 768)
# (1610, 768)
# (1611, 768)
# (1612, 768)
# (1613, 768)
# (1614, 768)
# (1614, 768)
# (1616, 6)
# (1616, 6)
