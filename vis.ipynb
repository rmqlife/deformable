# %%
import numpy as np
import matplotlib.pyplot as plt
names = list()
print names
# 1
names.append('/home/rmqlife/work/data/videos/npz/data_0918-1725.npz')
# 2
names.append('/home/rmqlife/work/data/videos/npz/data_0918-1540.npz')
# 3
names.append('/home/rmqlife/work/data/videos/npz/data_0918-2015.npz')
# 4
names.append('/home/rmqlife/work/data/videos/npz/data_0917-2135.npz')
# 5
names.append('/home/rmqlife/work/data/videos/npz/data_0918-2117.npz')
# 6
names.append('/home/rmqlife/work/data/videos/npz/data_0918-1534.npz')

print names
count = 1
for name in names:
    data = np.load(name)

    pos = data['pos']

    axes = plt.gca()
    axes.set_xlabel('time index')
    axes.set_ylabel('controller position')
    #axes.set_xticklabels([])

    plt.title('Training Set of Benchmark'+str(count))
    count = count+1
    for i in range(pos.shape[1]):
        plt.plot(range(pos.shape[0]),pos[:,i], label = 'DOF '+str(i))
    plt.legend()
    plt.show()
    
    print len(pos), int(0.3*len(pos))
# Out:
# []
# ['/home/rmqlife/work/data/videos/npz/data_0918-1725.npz', '/home/rmqlife/work/data/videos/npz/data_0918-1540.npz', '/home/rmqlife/work/data/videos/npz/data_0918-2015.npz', '/home/rmqlife/work/data/videos/npz/data_0917-2135.npz', '/home/rmqlife/work/data/videos/npz/data_0918-2117.npz', '/home/rmqlife/work/data/videos/npz/data_0918-1534.npz']
# 139 41
# 449 134
# 154 46
# 393 117
# 204 61
# 330 99
